# %% [markdown]
# Importing pandas.
# The import pandas statement instructs Python to import the pandas library into our environment. The as pd section of the code instructs Python to assign pandas the alias pd. we can utilize pandas functions by just typing pd.

# %%
import pandas as pd

# %% [markdown]
# •	Read in the data into a pandas dataframe.
#
# Loading and reading the csv file into the pandas dataframe, because the 4 first row of the csv file are empty we need to skip 4 rows to load and read the file.

# %%
df = pd.read_csv('API_EG.USE.PCAP.KG.OE_DS2_en_csv_v2_4028587.csv', skiprows=4)

# %% [markdown]
# •	Display the usual basic information (datatypes, names, non-null values for columns) about the dataframe.
#
# Method info() helps us to show the basic information of the Dataframe, including the number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column (non-null values). also we can use many other methods to show the information for example for showing the data type we can use datatype().

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            31 non-null     float64
#  5   1961            31 non-null     float64
#  6   1962            31 non-null     float64
#  7   1963            31 non-null     float64
#  8   1964            31 non-null     float64
#  9   1965            32 non-null     float64
#  10  1966            32 non-null     float64
#  11  1967            32 non-null     float64
#  12  1968            32 non-null     float64
#  13  1969            32 non-null     float64
#  14  1970            32 non-null     float64
#  15  1971            151 non-null    float64
#  16  1972            151 non-null    float64
# ...

# %% [markdown]
# •	Display the dataframe.
#
# For displying a dataframe just need to call the name of the dataframe, in this case our original dataframe name is df.

# %%
df
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                    Indicator Name     Indicator Code  1960  \
# 0    Energy use (kg of oil equivalent per capita)  EG.USE.PCAP.KG.OE   NaN
# 1    Energy use (kg of oil equivalent per capita)  EG.USE.PCAP.KG.OE   NaN
# 2    Energy use (kg of oil equivalent per capita)  EG.USE.PCAP.KG.OE   NaN
# 3    Energy use (kg of oil equivalent per capita)  EG.USE.PCAP.KG.OE   NaN
# ...

# %% [markdown]
# •	Find out what values occur under "Indicator Name".
#
# To find what values occures under 'Indicator Name' we use: df['Column'].values[number of index] we need to mention the column name and also mention the index number in values to show the value under a column.

# %%
df['Indicator Name'].values[0]
# Out:
# 'Energy use (kg of oil equivalent per capita)'

# %% [markdown]
# •	Set the name of the columns to the only value you found under "Indicator Name" (the columns and their labels remain the same!). (Apply the operation to your dataframe!)
#
# For naming a column we used df.rename_axis("the name prefered name", axis=1) when axis = 1 means columns and 0 means index, in this case we want to name a column, and for applying the operation to our dataframe we need to use inplace = True.

# %%
df.rename_axis('Energy use (kg of oil equivalent per capita)', axis= 1, inplace = True)
df
# Out:
# Energy use (kg of oil equivalent per capita)                 Country Name  \
# 0                                                                   Aruba
# 1                                             Africa Eastern and Southern
# 2                                                             Afghanistan
# 3                                              Africa Western and Central
# 4                                                                  Angola
# ..                                                                    ...
# 261                                                                Kosovo
# 262                                                           Yemen, Rep.
# 263                                                          South Africa
# 264                                                                Zambia
# 265                                                              Zimbabwe
#
# Energy use (kg of oil equivalent per capita) Country Code  \
# ...

# %% [markdown]
# •	Create a new dataframe dfcode which contains the "Country Code" and "Country Name" columns of your original dataframe. You will continue working with your original dataframe, in what follows, though.
#
# For creating a new dataframe as dfcode, we need to use dfcode equals to the original dataframe that name is df and mention the columns that we want to show in the dataframe, then by calling the new dataframe(dfcode) we can see the index, country name and values under it and country code and values under it.

# %%
dfcode = df[['Country Name','Country Code']]
dfcode
# Out:
# Energy use (kg of oil equivalent per capita)                 Country Name  \
# 0                                                                   Aruba
# 1                                             Africa Eastern and Southern
# 2                                                             Afghanistan
# 3                                              Africa Western and Central
# 4                                                                  Angola
# ..                                                                    ...
# 261                                                                Kosovo
# 262                                                           Yemen, Rep.
# 263                                                          South Africa
# 264                                                                Zambia
# 265                                                              Zimbabwe
#
# Energy use (kg of oil equivalent per capita) Country Code
# ...

# %% [markdown]
# •	Remove the "Country Code", "Indicator Name", "Indicator Code" columns. (Apply the operation to your dataframe!)
#
# For removing columns we can use drop() and mention the columns that we want to remove, then for applying it to the dataframe we need to set inplace True, and for mentioning that the names we mentioned are columns we set axis equals 1.

# %%
df.drop(['Country Code', 'Indicator Name', 'Indicator Code'], inplace=True, axis=1)
df
# Out:
# Energy use (kg of oil equivalent per capita)                 Country Name  \
# 0                                                                   Aruba
# 1                                             Africa Eastern and Southern
# 2                                                             Afghanistan
# 3                                              Africa Western and Central
# 4                                                                  Angola
# ..                                                                    ...
# 261                                                                Kosovo
# 262                                                           Yemen, Rep.
# 263                                                          South Africa
# 264                                                                Zambia
# 265                                                              Zimbabwe
#
# Energy use (kg of oil equivalent per capita)  1960  1961  1962  1963  1964  \
# ...

# %% [markdown]
# •	Make the column "Country Name" the index of your dataframe. (Apply the operation to your dataframe!)
#
# Using the df.set index() function and mentioning the column, we can replace an existing index with a column that we be the new index. for applying the operation to the dataframe we use inplace = True,

# %%
df.set_index('Country Name', inplace= True)
df
# Out:
# Energy use (kg of oil equivalent per capita)  1960  1961  1962  1963  1964  \
# Country Name
# Aruba                                          NaN   NaN   NaN   NaN   NaN
# Africa Eastern and Southern                    NaN   NaN   NaN   NaN   NaN
# Afghanistan                                    NaN   NaN   NaN   NaN   NaN
# Africa Western and Central                     NaN   NaN   NaN   NaN   NaN
# Angola                                         NaN   NaN   NaN   NaN   NaN
# ...                                            ...   ...   ...   ...   ...
# Kosovo                                         NaN   NaN   NaN   NaN   NaN
# Yemen, Rep.                                    NaN   NaN   NaN   NaN   NaN
# South Africa                                   NaN   NaN   NaN   NaN   NaN
# Zambia                                         NaN   NaN   NaN   NaN   NaN
# Zimbabwe                                       NaN   NaN   NaN   NaN   NaN
#
# ...

# %% [markdown]
# •	Get rid of columns which contain no values. (Apply the operation to your dataframe!)
#
# When we want to remove columns which contain no values we need to use df.dropna() it means remove na, and we need to mentioned the axis = 1 for the column and how = 'all' for clarifying that we want to remove columns that all of the values are na (not any value) which are years 2016 to 2021 and a column which is unnamed without value.

# %%
df.dropna(inplace= True, axis= 1, how='all')
df
# Out:
# Energy use (kg of oil equivalent per capita)  1960  1961  1962  1963  1964  \
# Country Name
# Aruba                                          NaN   NaN   NaN   NaN   NaN
# Africa Eastern and Southern                    NaN   NaN   NaN   NaN   NaN
# Afghanistan                                    NaN   NaN   NaN   NaN   NaN
# Africa Western and Central                     NaN   NaN   NaN   NaN   NaN
# Angola                                         NaN   NaN   NaN   NaN   NaN
# ...                                            ...   ...   ...   ...   ...
# Kosovo                                         NaN   NaN   NaN   NaN   NaN
# Yemen, Rep.                                    NaN   NaN   NaN   NaN   NaN
# South Africa                                   NaN   NaN   NaN   NaN   NaN
# Zambia                                         NaN   NaN   NaN   NaN   NaN
# Zimbabwe                                       NaN   NaN   NaN   NaN   NaN
#
# ...

# %% [markdown]
# •	Display the basic statistics by year, incl. minimal, maximal, mean, median, standard deviation values. (Make sure you display these values for all the years!)
# The describe() is a method that uses for calculating basic statistical such as percentile, mean, std, count, min and max, so we used df.describe() and cosidering that axis is 0 by default no need to mention it, because we want to show statistis for all years!

# %%
df.describe()
# Out:
# Energy use (kg of oil equivalent per capita)          1960          1961  \
# count                                            31.000000     31.000000
# mean                                           2385.557701   2420.522343
# std                                            1997.388654   1981.575639
# min                                             289.057068    322.490578
# 25%                                            1401.298789   1455.073445
# 50%                                            1906.174930   1937.644745
# 75%                                            2787.029421   2824.192050
# max                                           10523.406695  10534.018211
#
# Energy use (kg of oil equivalent per capita)          1962          1963  \
# count                                            31.000000     31.000000
# mean                                           2521.248064   2656.031388
# std                                            1971.311855   1992.182413
# ...

# %% [markdown]
# •	What can you conclude from the yearly descriptives? Answer in a markdown cell.
# -The count shows the number of values occur under each year(column).
#
# -The mean shows the average of all values of each year, sum of the values/nmber of values for each year.
#
# -The std shows standard deviation of all values of each year, It determines the amount of data dispersion of a set and is considered one of the most important scales in the field of descriptive statistics. For example, the std in 1960 is lower than in 1964, which means that the dispersion of values in 1960 is more toward the mean than in 1964.
#
# -25%,50%,75% In descriptive statistics, each of the three values that divides a set of ordered data into four equal parts is called a quartile. In this way, each of those sections represents a quarter of the sample or population.
#
# -min and max show us the minimum value and maximum value of each year.

# %% [markdown]
# •	Display the basic statistics by country, incl. minimal, maximal, mean, median, standard deviation values. (Make sure you display these values for all the countries!)
#
# For showing basic statistics by country we use describe but in this case that we need to calsulate the coulums based on rows(Countries) we need to mention the axis equals 1 and use apply to apply describe along an axis, and we created a new dataframe which is df2 to use it for next task.

# %%
df2 = df.apply(pd.DataFrame.describe, axis= 1)
df2
# Out:
#                              count         mean         std          min  \
# Country Name
# Aruba                          0.0          NaN         NaN          NaN
# Africa Eastern and Southern   44.0   774.382105   33.741279   725.668196
# Afghanistan                    0.0          NaN         NaN          NaN
# Africa Western and Central    44.0   569.449117   23.837452   511.982019
# Angola                        44.0   507.655185   57.699718   433.572486
# ...                            ...          ...         ...          ...
# Kosovo                        15.0  1216.102185  133.739458   908.608824
# Yemen, Rep.                   43.0   223.657474   75.290318    90.216323
# South Africa                  44.0  2486.783900  238.607050  1984.178909
# Zambia                        43.0   697.211345   92.585850   599.104868
# Zimbabwe                      43.0   857.661556   66.749616   724.292388
#
#                                      25%          50%          75%  \
# ...

# %% [markdown]
# •	Display the basic statistics of your previous by country-statistics (i.e., the mean of country means, etc.).
#
# To display the basic statistics of our previous calculation we also need to use describe but on the new dataframe we created (df2), it shows us for example mean of means that were on the previous calculations.

# %%
df2.describe()
# Out:
#             count          mean          std          min           25%  \
# count  266.000000    220.000000   219.000000   220.000000    220.000000
# mean    29.992481   1895.796955   456.997254  1105.604629   1617.384096
# std     20.445970   2368.170137   840.838073  1317.515592   1986.833783
# min      0.000000     12.400284     0.725879     9.548060      9.558898
# 25%      5.000000    520.734943    72.313997   333.756270    465.168462
# 50%     44.000000    999.663055   226.716363   538.671310    784.783249
# 75%     44.000000   2513.184092   515.951663  1442.352848   2257.972452
# max     56.000000  18278.542119  8751.700807  8775.992603  14525.570902
#
#                 50%           75%           max
# count    220.000000    220.000000    220.000000
# mean    1894.713150   2200.927342   2718.246666
# std     2310.093780   2902.359277   3974.368573
# min       11.760481     14.601868     16.532114
# 25%      534.788916    562.443391    657.513271
# ...

# %% [markdown]
# •	Display the first thirty rows of your original dataframe after sorting by the values for the last year in descending order. (Do not apply sorting to your original dataframe, just display!)
#
# For sorting values by for the last year(2015) we used df.sort_values() and we mentioned the last year of dataframe by df.columns[len(df.columns)-1] and for descending order we use ascending = Fals, and then we mention the head(30) to show the first 30 rows.

# %%
df.sort_values(df.columns[len(df.columns)-1], ascending = False).head(30)
# Out:
# Energy use (kg of oil equivalent per capita)          1960          1961  \
# Country Name
# Iceland                                        3082.711563   2916.706232
# Canada                                         4251.435911   4307.820754
# North America                                  5516.355617   5494.086457
# United States                                  5641.740755   5612.079503
# Luxembourg                                    10523.406695  10534.018211
# Finland                                        2196.953067   2252.778690
# Norway                                         1906.174930   1937.644745
# Australia                                      3063.554271   3115.787084
# Korea, Rep.                                            NaN           NaN
# Sweden                                         2698.792303   2742.123469
# Post-demographic dividend                      2812.288505   2848.671622
# Belgium                                        2519.497320   2570.815623
# ...

# %% [markdown]
# •	What are some of the conclusions you can draw from the data you displayed (e.g., about the "countries" in the data)?

# %% [markdown]
#  •	Calculate the difference between the (0-filled) values for the years 2010 and 2000 by country, sort it in a descending order, and display the first 30 rows. What are some of the conclusions you could draw from what you see?
#
# First we set zero instead of nan values then we calculate the difference between 2010 and 2000, for setting zero instead of nan we use numpy so first we need to import numpy as np, and then use df.replace(), then we use difference as a sundataframe that have the values of 2010-2000 and we sort it using difference.sort_values() in decsending order by set the ascending equals False and showing the first 30 rows by head(30).

# %%
import numpy as np
df.replace(np.nan, 0)
difference = df['2010']-df['2000']
difference.sort_values(ascending = False).head(30)
# Out:
# Country Name
# Trinidad and Tobago                            7343.881646
# Iceland                                        5931.617954
# Oman                                           2817.166090
# Saudi Arabia                                   2028.716721
# Gabon                                          1931.836600
# Kazakhstan                                     1837.648729
# Caribbean small states                         1773.999293
# Kuwait                                         1569.504601
# Brunei Darussalam                              1180.641360
# Turkmenistan                                   1164.474277
# Norway                                         1108.512430
# China                                          1055.735243
# Korea, Rep.                                    1042.816465
# Gibraltar                                      1037.278934
# Iran, Islamic Rep.                              894.791886
# Estonia                                         848.028800
# ...

# %% [markdown]
# •	Display the mean values by year as a percentage of the maximal values for that year (e.g., if the mean value for 1965 were 200, and the maximal for 1965 were 400, then for 1965, you should be displaying 50).
#
# -First we need calculate the mean of dataframe by df.mean() and then calculate the max of dataframe by df.max divid the mean on max then multiply by 100, we combined this process like df3 = df.mean()/df.max*100.

# %%
df3 = df.mean()/df.max()*100
df3
# Out:
# Energy use (kg of oil equivalent per capita)
# 1960    22.669063
# 1961    22.978148
# 1962    24.208922
# 1963    25.378166
# 1964    24.790614
# 1965    25.704887
# 1966    27.558484
# 1967    28.676396
# 1968    28.423581
# 1969    27.937783
# 1970    29.908848
# 1971     4.648137
# 1972     4.854237
# 1973     4.650674
# 1974     4.936191
# 1975     6.891470
# 1976     6.512473
# 1977     6.714076
# 1978     7.621300
# 1979     7.911123
# 1980     7.606008
# 1981     7.969176
# 1982     7.358451
# 1983     6.937944
# 1984    10.107683
# 1985    13.011385
# 1986    13.287579
# 1987    13.817290
# 1988    14.030779
# 1989    14.496496
# 1990    14.650733
# 1991    14.829843
# 1992    13.987773
# 1993    13.492196
# 1994    13.526670
# 1995    13.459529
# 1996    13.153490
# 1997    11.766205
# 1998    11.653551
# 1999    11.285838
# 2000    12.071856
# 2001    11.602816
# 2002    10.760776
# 2003    11.293554
# 2004     9.663841
# 2005    11.080832
# 2006    11.429581
# ...

# %% [markdown]
# •	Display the countries (not the subdataframe, just the countries!) where the values for all years are missing.
#
# To display coutries which don't have values for all years we use df.isna(), isna function looks for missing values on dataframe and shows the indexes which don't have values for all years.

# %%
df[df.isna()]
# Out:
# Energy use (kg of oil equivalent per capita)  1960  1961  1962  1963  1964  \
# Country Name
# Aruba                                          NaN   NaN   NaN   NaN   NaN
# Africa Eastern and Southern                    NaN   NaN   NaN   NaN   NaN
# Afghanistan                                    NaN   NaN   NaN   NaN   NaN
# Africa Western and Central                     NaN   NaN   NaN   NaN   NaN
# Angola                                         NaN   NaN   NaN   NaN   NaN
# ...                                            ...   ...   ...   ...   ...
# Kosovo                                         NaN   NaN   NaN   NaN   NaN
# Yemen, Rep.                                    NaN   NaN   NaN   NaN   NaN
# South Africa                                   NaN   NaN   NaN   NaN   NaN
# Zambia                                         NaN   NaN   NaN   NaN   NaN
# Zimbabwe                                       NaN   NaN   NaN   NaN   NaN
#
# ...

# %% [markdown]
# •	Display the subdataframe with the countries whose final year's values are bigger than the final year values' mean.
#
# Using df.loc[] helps us to access to rows or columns by label or boolean array, we need to calculate the mean of last year column(2015) and then see which values of last year(using df.loc[]) are bigger than means of it and show the results.

# %%
df4 = df.loc[df[df.columns[len(df.columns)-1]] > df[df.columns[len(df.columns)-1]].mean()]
df4
# Out:
# Energy use (kg of oil equivalent per capita)          1960          1961  \
# Country Name
# Australia                                      3063.554271   3115.787084
# Belgium                                        2519.497320   2570.815623
# Canada                                         4251.435911   4307.820754
# Finland                                        2196.953067   2252.778690
# High income                                    2761.770337   2799.712478
# Iceland                                        3082.711563   2916.706232
# Korea, Rep.                                            NaN           NaN
# Luxembourg                                    10523.406695  10534.018211
# North America                                  5516.355617   5494.086457
# Netherlands                                    1825.934253   1879.150201
# Norway                                         1906.174930   1937.644745
# New Zealand                                    1685.788431   1763.259908
# ...

# %% [markdown]
# •	Load the "capital.json" file, and arrive at a dataframe capitaldf containing the name, capital, iso2, iso3 information (these three should end up as the columns) for every country in it.
#
# For loading the capital.json into a dataframe and read it we use pd.read_json("json file path") we named it capitaldf.

# %%
capitaldf = pd.read_json('capital.json')
capitaldf
# Out:
#      error                               msg  \
# 0    False  countries and capitals retrieved
# 1    False  countries and capitals retrieved
# 2    False  countries and capitals retrieved
# 3    False  countries and capitals retrieved
# 4    False  countries and capitals retrieved
# ..     ...                               ...
# 246  False  countries and capitals retrieved
# 247  False  countries and capitals retrieved
# 248  False  countries and capitals retrieved
# 249  False  countries and capitals retrieved
# 250  False  countries and capitals retrieved
#
#                                                   data
# 0    {'name': 'Afghanistan', 'capital': 'Kabul', 'i...
# 1    {'name': 'Aland Islands', 'capital': 'Marieham...
# 2    {'name': 'Albania', 'capital': 'Tirana', 'iso2...
# 3    {'name': 'Algeria', 'capital': 'Algiers', 'iso...
# 4    {'name': 'American Samoa', 'capital': 'Pago Pa...
# ..                                                 ...
# ...

# %% [markdown]
# To make

# %%
cap = pd.json_normalize(capitaldf['data'])
cap
# Out:
#                   name    capital iso2 iso3
# 0          Afghanistan      Kabul   AF  AFG
# 1        Aland Islands  Mariehamn   AX  ALA
# 2              Albania     Tirana   AL  ALB
# 3              Algeria    Algiers   DZ  DZA
# 4       American Samoa  Pago Pago   AS  ASM
# ..                 ...        ...  ...  ...
# 246  Wallis and Futuna   Mata Utu   WF  WLF
# 247     Western Sahara   El-Aaiun   EH  ESH
# 248              Yemen      Sanaa   YE  YEM
# 249             Zambia     Lusaka   ZM  ZMB
# 250           Zimbabwe     Harare   ZW  ZWE
#
# [251 rows x 4 columns]

# %% [markdown]
# •	Find the subdataframe of the dfcode dataframe you created earlier on where the "Country Code" value is not in the "iso3" column of capitaldf. Hint: look up and use the .isin pandas Series method. Store this subdataframe in the variable dfnocode. Display dfnocode and explain in a markdown cell what you see and what this could be used for.
#
# To look for the country codes in dfcode that are not in the iso3 in dfcode we use

# %%
dfnocode = dfcode.loc[~dfcode['Country Code'].isin(cap['iso3'])]
dfnocode
# Out:
#                                                                                    Country Name  \
# Energy use (kg of oil equivalent per capita)
# 1                                                                   Africa Eastern and Southern
# 3                                                                    Africa Western and Central
# 7                                                                                    Arab World
# 36                                                               Central Europe and the Baltics
# 38                                                                              Channel Islands
# 49                                                                       Caribbean small states
# 61                                                  East Asia & Pacific (excluding high income)
# 62                                                                   Early-demographic dividend
# ...

# %%
subdf = df.loc[~df.index.isin(dfnocode['Country Name'])]
subdf
# Out:
#               1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  \
# Country Name                                                              ...
# Aruba          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Afghanistan    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Angola         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Albania        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Andorra        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# Kosovo         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Yemen, Rep.    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# South Africa   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Zambia         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...
